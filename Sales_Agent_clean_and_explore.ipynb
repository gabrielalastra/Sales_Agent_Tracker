# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
path = '/content/wizardUSA_orders.xlsx'

# %%
df = pd.read_excel(path)
df.tail()
# Out:
# /usr/local/lib/python3.7/dist-packages/openpyxl/worksheet/header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 7380    9987  CA-125794-9987 2019-09-29 2019-10-03  Standard Class
# 7381    9990  CA-110422-9990 2017-01-21 2017-01-23    Second Class
# 7382    9991  CA-121258-9991 2020-02-26 2020-03-03  Standard Class
# 7383    9992  CA-121258-9992 2020-02-26 2020-03-03  Standard Class
# 7384    9993  CA-121258-9993 2020-02-26 2020-03-03  Standard Class
#
#      Customer ID     Customer Name  Sales Agent ID Country/Region  \
# 7380    ML-17410      Maris LaWare             4.0  United States
# 7381    TB-21400  Tom Boeckenhauer             9.0  United States
# 7382    DB-13060       Dave Brooks             4.0  United States
# 7383    DB-13060       Dave Brooks             4.0  United States
# ...

# %%
df.isnull().value_counts()
# Out:
# Row ID  Order ID  Order Date  Ship Date  Ship Mode  Customer ID  Customer Name  Sales Agent ID  Country/Region  City   State  Postal Code  Region  Product ID  Category  Sub-Category  Product Name  Sales  Quantity  Cost%
# False   False     False       False      False      False        False          False           False           False  False  False        False   False       False     False         False         False  False     False    7324
#                                                                                 True            False           False  False  False        False   False       False     False         False         False  False     False      51
#                                                                                 False           False           False  False  True         False   False       False     False         False         False  False     False      10
# dtype: int64

# %%
df.isna().value_counts()
# Out:
# Row ID  Order ID  Order Date  Ship Date  Ship Mode  Customer ID  Customer Name  Sales Agent ID  Country/Region  City   State  Postal Code  Region  Product ID  Category  Sub-Category  Product Name  Sales  Quantity  Cost%
# False   False     False       False      False      False        False          False           False           False  False  False        False   False       False     False         False         False  False     False    7324
#                                                                                 True            False           False  False  False        False   False       False     False         False         False  False     False      51
#                                                                                 False           False           False  False  True         False   False       False     False         False         False  False     False      10
# dtype: int64

# %%
df['Sales Agent ID'].value_counts()

# %%
mask = df['Sales Agent ID'].isnull()
mask = df[mask]
mask
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 71        80    CA-127208-80 2019-06-12 2019-06-15     First Class
# 72        81    CA-127208-81 2019-06-12 2019-06-15     First Class
# 429      534   CA-168753-534 2019-05-29 2019-06-01    Second Class
# 430      535   CA-168753-535 2019-05-29 2019-06-01    Second Class
# 1121    1432  CA-120768-1432 2017-12-19 2017-12-21    Second Class
# 1122    1433  CA-120768-1433 2017-12-19 2017-12-21    Second Class
# 1123    1434  CA-120768-1434 2017-12-19 2017-12-21    Second Class
# 1134    1452  CA-133711-1452 2019-11-26 2019-11-29     First Class
# 1135    1453  CA-133711-1453 2019-11-26 2019-11-29     First Class
# 1136    1454  CA-133711-1454 2019-11-26 2019-11-29     First Class
# 1137    1455  CA-133711-1455 2019-11-26 2019-11-29     First Class
# 1219    1578  CA-154403-1578 2019-05-23 2019-05-27  Standard Class
# 1499    1976  CA-110408-1976 2017-10-18 2017-10-20    Second Class
# ...

# %% [markdown]
# <h4>
# In this project that's no reason to keep the Sales data without the Sales Agent ID
# </h4>

# %%
df = df.drop(df[df['Sales Agent ID'].isna() == True].index)

# %%
mask = df['Sales Agent ID'].isnull()
mask = df[mask]
mask
# Out:
# Empty DataFrame
# Columns: [Row ID, Order ID, Order Date, Ship Date, Ship Mode, Customer ID, Customer Name, Sales Agent ID, Country/Region, City, State, Postal Code, Region, Product ID, Category, Sub-Category, Product Name, Sales, Quantity, Cost%]
# Index: []

# %%
mask = df['Postal Code'].isnull()
mask = df[mask]
mask
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 3925    5275  CA-162887-5275 2018-11-07 2018-11-09    Second Class
# 6500    8799  US-150140-8799 2019-04-06 2019-04-10  Standard Class
# 6745    9147  US-165505-9147 2019-01-23 2019-01-27  Standard Class
# 6746    9148  US-165505-9148 2019-01-23 2019-01-27  Standard Class
# 6747    9149  US-165505-9149 2019-01-23 2019-01-27  Standard Class
# 6912    9387  US-127292-9387 2020-01-19 2020-01-23  Standard Class
# 6913    9388  US-127292-9388 2020-01-19 2020-01-23  Standard Class
# 6914    9389  US-127292-9389 2020-01-19 2020-01-23  Standard Class
# 6915    9390  US-127292-9390 2020-01-19 2020-01-23  Standard Class
# 7173    9742  CA-117086-9742 2018-11-08 2018-11-12  Standard Class
#
#      Customer ID     Customer Name  Sales Agent ID Country/Region        City  \
# 3925    SV-20785  Stewart Visinsky            44.0  United States  Burlington
# ...

# %%
city = 'Burlington'
postcode = '05402'
columnP= 'Postal Code'

cond = (df['City'] == 'Burlington')
df.loc[cond,columnP] = postcode

# %%
mask = df['Postal Code'].isnull()
mask = df[mask]
mask
# Out:
# Empty DataFrame
# Columns: [Row ID, Order ID, Order Date, Ship Date, Ship Mode, Customer ID, Customer Name, Sales Agent ID, Country/Region, City, State, Postal Code, Region, Product ID, Category, Sub-Category, Product Name, Sales, Quantity, Cost%]
# Index: []

# %%
sns.heatmap(df.corr())

# %%
columns = ['Ship Mode','Region', 'Category', 'Sub-Category']
for i in columns:
  plt.figure(figsize=[30,6])
  g=sns.countplot(x=i, data=df)
  plt.show()

# %%
plt.figure(figsize=[40,6])
g = sns.countplot(x='State', data=df)
g.set_xticklabels(g.get_xticklabels(), rotation=30)
plt.title('\nSales per State\n', size=30)
plt.show()

# %%
df2 = pd.read_excel('/content/wizardUSA_salesagents.xlsx')
df2.head()
# Out:
#    Sales Agent Id      Name  Surname      Level       State  Age
# 0               1    Emmett     Rios     Junior     Alabama   27
# 1               2   Annette   Little  Mid-Level     Arizona   33
# 2               3    Isabel   Barnes     Junior    Arkansas   29
# 3               4  Santiago   Howard  Executive  California   55
# 4               5     Louis  Aguilar  Mid-Level    Colorado   38

# %%
df2.isnul().value_counts()
# Out:
# Sales Agent Id  Name   Surname  Level  State  Age
# False           False  False    False  False  False    49
# dtype: int64

# %%
df2.isna().value_counts()
# Out:
# Sales Agent Id  Name   Surname  Level  State  Age
# False           False  False    False  False  False    49
# dtype: int64

# %%
col = ['Level', 'Age']
for i in col:
  plt.figure(figsize=[10,6])
  g=sns.countplot(x=i, data=df2)
  plt.show()

# %%
df.to_excel('wizardUSA_ordersClean.xlsx', index=False)
